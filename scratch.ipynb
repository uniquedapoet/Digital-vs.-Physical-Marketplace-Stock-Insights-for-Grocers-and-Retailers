# %%
# Install necessary dependencies
# !pip install yfinance altair pandas plotly matplotlib numpy
# Out:
# Requirement already satisfied: yfinance in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (0.2.44)
# Requirement already satisfied: altair in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (5.4.1)
# Requirement already satisfied: pandas in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: plotly in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (5.22.0)
# Requirement already satisfied: matplotlib in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: numpy in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (1.23.5)
# Requirement already satisfied: requests>=2.31 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from yfinance) (1.1)
# Requirement already satisfied: jinja2 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from altair) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from altair) (4.19.2)
# Requirement already satisfied: narwhals>=1.5.2 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from altair) (1.7.0)
# Requirement already satisfied: packaging in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from altair) (23.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from altair) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair) (0.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/eduardobenjamin/anaconda3/lib/python3.11/site-packages (from jinja2->altair) (2.1.3)

# %%
from existing_functions import *

# %%
stock_data = get_stock_data('NVDA')
stock_data = add_columns(stock_data)
stock_data
# Out:
# Adding columns...
# Halfway There...
#       index                      Date        Open        High         Low  \
# 0         0 2014-11-10 00:00:00-05:00    0.472536    0.481619    0.471341
# 1         1 2014-11-11 00:00:00-05:00    0.475643    0.478272    0.468712
# 2         2 2014-11-12 00:00:00-05:00    0.471102    0.472297    0.463214
# 3         3 2014-11-13 00:00:00-05:00    0.471341    0.472058    0.463453
# 4         4 2014-11-14 00:00:00-05:00    0.467756    0.473014    0.463214
# ...     ...                       ...         ...         ...         ...
# 2512   2512 2024-11-04 00:00:00-05:00  137.210007  138.960007  135.570007
# 2513   2513 2024-11-05 00:00:00-05:00  137.449997  140.369995  137.330002
# 2514   2514 2024-11-06 00:00:00-05:00  142.960007  146.490005  141.960007
# 2515   2515 2024-11-07 00:00:00-05:00  146.389999  148.929993  146.169998
# 2516   2516 2024-11-08 00:00:00-05:00  148.770004  149.759995  146.259995
#
#            Close     Volume  Dividends  Stock Splits Symbol  ...  \
# 0       0.478511  293388000        0.0           0.0   NVDA  ...
# 1       0.472775  212992000        0.0           0.0   NVDA  ...
# 2       0.469668  204584000        0.0           0.0   NVDA  ...
# 3       0.467278  225328000        0.0           0.0   NVDA  ...
# 4       0.473014  160248000        0.0           0.0   NVDA  ...
# ...          ...        ...        ...           ...    ...  ...
# 2512  136.050003  187528200        0.0           0.0   NVDA  ...
# 2513  139.910004  160537400        0.0           0.0   NVDA  ...
# 2514  145.610001  242043900        0.0           0.0   NVDA  ...
# 2515  148.880005  205840400        0.0           0.0   NVDA  ...
# 2516  147.429993  110667043        0.0           0.0   NVDA  ...
#
#       Resistance_20_Day  Support_20_Day  Resistance_50_Day  Support_50_Day  \
# 0              0.000000        0.000000           0.000000        0.000000
# 1              0.000000        0.000000           0.000000        0.000000
# 2              0.000000        0.000000           0.000000        0.000000
# 3              0.000000        0.000000           0.000000        0.000000
# 4              0.000000        0.000000           0.000000        0.000000
# ...                 ...             ...                ...             ...
# 2512         143.710007      131.600006         143.710007      102.821205
# 2513         143.710007      131.600006         143.710007      102.821205
# 2514         145.610001      131.600006         145.610001      102.821205
# 2515         148.880005      131.600006         148.880005      102.821205
# 2516         148.880005      131.600006         148.880005      102.821205
#
#       Volume_MA_10  Volume_MA_20  Volume_MA_50  Optimal_Action   Z-score  \
# 0              0.0  0.000000e+00  0.000000e+00            Hold -0.630066
# 1              0.0  0.000000e+00  0.000000e+00            Hold -0.630263
# 2              0.0  0.000000e+00  0.000000e+00            Hold -0.630370
# 3              0.0  0.000000e+00  0.000000e+00            Hold -0.630452
# 4              0.0  0.000000e+00  0.000000e+00            Hold -0.630255
# ...            ...           ...           ...             ...       ...
# 2512   206501260.0  2.315793e+08  2.832952e+08            Hold  4.018953
# 2513   199923840.0  2.253201e+08  2.798666e+08            Hold  4.151320
# 2514   195535230.0  2.251127e+08  2.786448e+08            Hold  4.346785
# 2515   198883780.0  2.232891e+08  2.737996e+08            Hold  4.458920
# 2516   189438274.3  2.203120e+08  2.669525e+08            Hold  4.409196
#
#                OBV
# 0                0
# 1       -212992000
# 2       -417576000
# 3       -642904000
# 4       -482656000
# ...            ...
# 2512  106865446900
# 2513  107025984300
# 2514  107268028200
# 2515  107473868600
# 2516  107363201557
#
# [2517 rows x 79 columns]

# %%
plot_closing_price(stock_data)
# Out:
# alt.Chart(...)

# %%
plot_candlestick(stock_data, ['2024-08-01','2024-10-31'],20)

# %%
closing_price = plot_closing_price(stock_data,0.5)
MA_10 = plot_moving_average(stock_data, 10)
MA_20 = plot_moving_average(stock_data, 20)
MA_50 = plot_moving_average(stock_data, 50)
MA_200 = plot_moving_average(stock_data, 200)
short_term_MA = alt.layer(MA_10, MA_20, closing_price)
medium_term_MA = alt.layer(MA_200, MA_50, closing_price)
MA_charts = alt.vconcat(short_term_MA, medium_term_MA)
MA_charts
# Out:
# alt.VConcatChart(...)

# %%
plot_bollinger_bands(stock_data, 50)

# %%
plot_RSI(stock_data)
# Out:
# <module 'matplotlib.pyplot' from '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
plot_MACD(stock_data)

# %%
stock_data.columns
# Out:
# Index(['index', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Symbol', '1_Day_Return', '5_Day_Return',
#        '10_Day_Return', '20_Day_Return', '50_Day_Return', '200_Day_Return',
#        'Best_Return_Window', 'Best_Return', 'close_lag1', 'close_lag2',
#        'close_lag3', 'close_lag4', 'close_lag5', 'volume_lag1', 'volume_lag2',
#        'volume_lag3', 'volume_lag4', 'volume_lag5', 'MA_10', 'MA_20', 'MA_50',
#        'MA_200', 'std_10', 'std_20', 'std_50', 'std_200', 'upper_band_10',
#        'lower_band_10', 'upper_band_20', 'lower_band_20', 'upper_band_50',
#        'lower_band_50', 'upper_band_200', 'lower_band_200',
#        'Golden_Cross_Short', 'Golden_Cross_Medium', 'Golden_Cross_Long',
#        'Death_Cross_Short', 'Death_Cross_Medium', 'Death_Cross_Long',
#        'RSI_10_Day', 'ROC', 'AVG_Volume_10', 'AVG_Volume_20', 'AVG_Volume_50',
#        'AVG_Volume_200', 'EMA_short', 'EMA_long', 'MACD', 'Signal',
#        'MACD_Hist', 'Previous_Close', 'TR', 'ATR', '10_Day_ROC', '20_Day_ROC',
#        '50_Day_ROC', 'Resistance_10_Day', 'Support_10_Day',
#        'Resistance_20_Day', 'Support_20_Day', 'Resistance_50_Day',
#        'Support_50_Day', 'Volume_MA_10', 'Volume_MA_20', 'Volume_MA_50',
#        'Optimal_Action', 'Z-score', 'OBV'],
#       dtype='object')
